# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Obeservations:
# 1.  Tempearature has a strong correlation with latitude, the closer to the equator, the higher the temperature
# 2.  Cloudiness and wind speed do not correlate with latitude
# 3.  Southern hempisphere is warmer than northern hemipshere, due to the time of year (winter in northern hemispher and summer in southern hemipshere)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units="imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
set_list=1
record=0

cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]
city2=[]

print("Beginning Data Retrieval")
print("-----------------------------")
#gather current weather data
for city in cities:
    
    record=record+1
    try:
        print(f"Processing Record {record} of Set {set_list}  | {city}")
        response=requests.get(query_url+city).json()
        
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        city2.append(city)
    except KeyError:
        print("City not found. Skipping...")
    if record==50:
        record=0
        set_list=set_list+1
        time.sleep(50)
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1  | busselton
# Processing Record 2 of Set 1  | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1  | kahului
# Processing Record 4 of Set 1  | matara
# Processing Record 5 of Set 1  | tasiilaq
# Processing Record 6 of Set 1  | lata
# Processing Record 7 of Set 1  | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1  | neubrandenburg
# Processing Record 9 of Set 1  | punta arenas
# Processing Record 10 of Set 1  | rikitea
# Processing Record 11 of Set 1  | kot diji
# Processing Record 12 of Set 1  | aktau
# Processing Record 13 of Set 1  | torbay
# Processing Record 14 of Set 1  | komsomolskiy
# Processing Record 15 of Set 1  | mount gambier
# Processing Record 16 of Set 1  | arraial do cabo
# Processing Record 17 of Set 1  | barrow
# Processing Record 18 of Set 1  | nhamunda
# Processing Record 19 of Set 1  | rybnaya sloboda
# Processing Record 20 of Set 1  | vila velha
# Processing Record 21 of Set 1  | sao filipe
# Processing Record 22 of Set 1  | grao mogol
# City not found. Skipping...
# Processing Record 23 of Set 1  | iqaluit
# Processing Record 24 of Set 1  | rio tuba
# Processing Record 25 of Set 1  | bjornevatn
# Processing Record 26 of Set 1  | albany
# Processing Record 27 of Set 1  | nikolskoye
# Processing Record 28 of Set 1  | hithadhoo
# Processing Record 29 of Set 1  | victoria
# Processing Record 30 of Set 1  | phek
# Processing Record 31 of Set 1  | ponta do sol
# Processing Record 32 of Set 1  | guerrero negro
# Processing Record 33 of Set 1  | necochea
# Processing Record 34 of Set 1  | norman wells
# Processing Record 35 of Set 1  | la ronge
# Processing Record 36 of Set 1  | lufilufi
# Processing Record 37 of Set 1  | hilo
# Processing Record 38 of Set 1  | comodoro rivadavia
# Processing Record 39 of Set 1  | east london
# Processing Record 40 of Set 1  | tabou
# Processing Record 41 of Set 1  | kodiak
# Processing Record 42 of Set 1  | cape town
# Processing Record 43 of Set 1  | pavino
# Processing Record 44 of Set 1  | longyearbyen
# Processing Record 45 of Set 1  | vila franca do campo
# Processing Record 46 of Set 1  | moscow
# Processing Record 47 of Set 1  | severodvinsk
# Processing Record 48 of Set 1  | yellowknife
# Processing Record 49 of Set 1  | xingtai
# Processing Record 50 of Set 1  | jamestown
# Processing Record 1 of Set 2  | qaanaaq
# Processing Record 2 of Set 2  | ilek
# Processing Record 3 of Set 2  | new norfolk
# Processing Record 4 of Set 2  | rundu
# Processing Record 5 of Set 2  | corvallis
# Processing Record 6 of Set 2  | vaini
# Processing Record 7 of Set 2  | esso
# Processing Record 8 of Set 2  | ushuaia
# Processing Record 9 of Set 2  | santa
# Processing Record 10 of Set 2  | muli
# Processing Record 11 of Set 2  | camacha
# Processing Record 12 of Set 2  | chokurdakh
# Processing Record 13 of Set 2  | bengkulu
# City not found. Skipping...
# Processing Record 14 of Set 2  | vestmannaeyjar
# Processing Record 15 of Set 2  | tungi
# Processing Record 16 of Set 2  | teruel
# Processing Record 17 of Set 2  | kapit
# Processing Record 18 of Set 2  | khatanga
# Processing Record 19 of Set 2  | parambu
# Processing Record 20 of Set 2  | saint-georges
# Processing Record 21 of Set 2  | adilabad
# Processing Record 22 of Set 2  | ostrovnoy
# Processing Record 23 of Set 2  | tuktoyaktuk
# Processing Record 24 of Set 2  | gobabis
# Processing Record 25 of Set 2  | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 2  | leningradskiy
# Processing Record 27 of Set 2  | jumla
# Processing Record 28 of Set 2  | saint-joseph
# Processing Record 29 of Set 2  | kapaa
# Processing Record 30 of Set 2  | poyarkovo
# Processing Record 31 of Set 2  | palmer
# Processing Record 32 of Set 2  | upernavik
# Processing Record 33 of Set 2  | flinders
# Processing Record 34 of Set 2  | thompson
# Processing Record 35 of Set 2  | ye
# City not found. Skipping...
# Processing Record 36 of Set 2  | hobart
# Processing Record 37 of Set 2  | mantua
# Processing Record 38 of Set 2  | asha
# Processing Record 39 of Set 2  | mitchell
# Processing Record 40 of Set 2  | bredasdorp
# Processing Record 41 of Set 2  | pajapan
# Processing Record 42 of Set 2  | chicama
# Processing Record 43 of Set 2  | bababe
# City not found. Skipping...
# Processing Record 44 of Set 2  | bluff
# Processing Record 45 of Set 2  | bawal
# Processing Record 46 of Set 2  | ganzhou
# Processing Record 47 of Set 2  | butaritari
# Processing Record 48 of Set 2  | carnarvon
# Processing Record 49 of Set 2  | gueret
# Processing Record 50 of Set 2  | kasangulu
# Processing Record 1 of Set 3  | haines junction
# Processing Record 2 of Set 3  | port alfred
# Processing Record 3 of Set 3  | monterey
# Processing Record 4 of Set 3  | totness
# Processing Record 5 of Set 3  | hasaki
# Processing Record 6 of Set 3  | salalah
# Processing Record 7 of Set 3  | mataura
# Processing Record 8 of Set 3  | san patricio
# Processing Record 9 of Set 3  | berlevag
# Processing Record 10 of Set 3  | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 3  | talnakh
# Processing Record 12 of Set 3  | genhe
# Processing Record 13 of Set 3  | cayenne
# Processing Record 14 of Set 3  | biak
# Processing Record 15 of Set 3  | avarua
# Processing Record 16 of Set 3  | todireni
# Processing Record 17 of Set 3  | kieta
# Processing Record 18 of Set 3  | ribeira grande
# Processing Record 19 of Set 3  | te anau
# Processing Record 20 of Set 3  | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 3  | caravelas
# Processing Record 22 of Set 3  | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 3  | rocha
# Processing Record 24 of Set 3  | villazon
# City not found. Skipping...
# Processing Record 25 of Set 3  | kuhdasht
# Processing Record 26 of Set 3  | tiznit
# Processing Record 27 of Set 3  | kavieng
# Processing Record 28 of Set 3  | port lincoln
# Processing Record 29 of Set 3  | esperance
# Processing Record 30 of Set 3  | port elizabeth
# Processing Record 31 of Set 3  | mnogovershinnyy
# Processing Record 32 of Set 3  | kuminskiy
# Processing Record 33 of Set 3  | takoradi
# Processing Record 34 of Set 3  | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 3  | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3  | otradnoye
# Processing Record 37 of Set 3  | obo
# Processing Record 38 of Set 3  | nichinan
# Processing Record 39 of Set 3  | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3  | puerto ayora
# Processing Record 41 of Set 3  | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3  | hami
# Processing Record 43 of Set 3  | honningsvag
# Processing Record 44 of Set 3  | dikson
# Processing Record 45 of Set 3  | batagay
# Processing Record 46 of Set 3  | chernyshevskiy
# Processing Record 47 of Set 3  | tilichiki
# Processing Record 48 of Set 3  | mehamn
# Processing Record 49 of Set 3  | lebu
# Processing Record 50 of Set 3  | burnie
# Processing Record 1 of Set 4  | ibra
# Processing Record 2 of Set 4  | morondava
# Processing Record 3 of Set 4  | alotau
# City not found. Skipping...
# Processing Record 4 of Set 4  | galle
# Processing Record 5 of Set 4  | puerto del rosario
# Processing Record 6 of Set 4  | tuatapere
# Processing Record 7 of Set 4  | rawson
# Processing Record 8 of Set 4  | ouro fino
# Processing Record 9 of Set 4  | otane
# Processing Record 10 of Set 4  | san quintin
# Processing Record 11 of Set 4  | mount isa
# Processing Record 12 of Set 4  | natchitoches
# Processing Record 13 of Set 4  | helong
# Processing Record 14 of Set 4  | fairbanks
# Processing Record 15 of Set 4  | praia da vitoria
# Processing Record 16 of Set 4  | saquena
# Processing Record 17 of Set 4  | porbandar
# Processing Record 18 of Set 4  | port-gentil
# Processing Record 19 of Set 4  | lolua
# City not found. Skipping...
# Processing Record 20 of Set 4  | bethel
# Processing Record 21 of Set 4  | beringovskiy
# Processing Record 22 of Set 4  | yablonovo
# Processing Record 23 of Set 4  | suzun
# Processing Record 24 of Set 4  | karaul
# City not found. Skipping...
# Processing Record 25 of Set 4  | atuona
# Processing Record 26 of Set 4  | ixtapa
# Processing Record 27 of Set 4  | port hardy
# Processing Record 28 of Set 4  | geraldton
# Processing Record 29 of Set 4  | yar-sale
# Processing Record 30 of Set 4  | katherine
# Processing Record 31 of Set 4  | souillac
# Processing Record 32 of Set 4  | brae
# Processing Record 33 of Set 4  | georgetown
# Processing Record 34 of Set 4  | maloyaroslavets
# Processing Record 35 of Set 4  | castro
# Processing Record 36 of Set 4  | chernyy yar
# Processing Record 37 of Set 4  | vardo
# Processing Record 38 of Set 4  | doctor arroyo
# Processing Record 39 of Set 4  | arlit
# Processing Record 40 of Set 4  | fukue
# Processing Record 41 of Set 4  | yulara
# Processing Record 42 of Set 4  | qujing
# Processing Record 43 of Set 4  | faanui
# Processing Record 44 of Set 4  | luderitz
# Processing Record 45 of Set 4  | kalanguy
# Processing Record 46 of Set 4  | padrauna
# Processing Record 47 of Set 4  | kavaratti
# Processing Record 48 of Set 4  | roald
# Processing Record 49 of Set 4  | cidreira
# Processing Record 50 of Set 4  | balkanabat
# Processing Record 1 of Set 5  | ilulissat
# Processing Record 2 of Set 5  | taicheng
# Processing Record 3 of Set 5  | amderma
# City not found. Skipping...
# Processing Record 4 of Set 5  | kalmar
# Processing Record 5 of Set 5  | kruisfontein
# Processing Record 6 of Set 5  | marcona
# City not found. Skipping...
# Processing Record 7 of Set 5  | sibut
# Processing Record 8 of Set 5  | saint george
# Processing Record 9 of Set 5  | porto nacional
# Processing Record 10 of Set 5  | kysyl-syr
# Processing Record 11 of Set 5  | lovozero
# Processing Record 12 of Set 5  | cap malheureux
# Processing Record 13 of Set 5  | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 5  | canmore
# Processing Record 15 of Set 5  | san pedro
# Processing Record 16 of Set 5  | hermanus
# Processing Record 17 of Set 5  | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 5  | adrian
# Processing Record 19 of Set 5  | pekan
# Processing Record 20 of Set 5  | verkhnyaya inta
# Processing Record 21 of Set 5  | quatre cocos
# Processing Record 22 of Set 5  | vostok
# Processing Record 23 of Set 5  | lorengau
# Processing Record 24 of Set 5  | kailua
# Processing Record 25 of Set 5  | san cristobal
# Processing Record 26 of Set 5  | marsa matruh
# Processing Record 27 of Set 5  | banyo
# Processing Record 28 of Set 5  | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5  | egvekinot
# Processing Record 30 of Set 5  | la sarre
# Processing Record 31 of Set 5  | marienburg
# Processing Record 32 of Set 5  | yamethin
# Processing Record 33 of Set 5  | kalmunai
# Processing Record 34 of Set 5  | manzanillo
# Processing Record 35 of Set 5  | sao jose da coroa grande
# Processing Record 36 of Set 5  | bambous virieux
# Processing Record 37 of Set 5  | umm kaddadah
# Processing Record 38 of Set 5  | buluang
# Processing Record 39 of Set 5  | thyboron
# Processing Record 40 of Set 5  | alofi
# Processing Record 41 of Set 5  | mugla
# Processing Record 42 of Set 5  | inongo
# Processing Record 43 of Set 5  | los llanos de aridane
# Processing Record 44 of Set 5  | puerto rondon
# Processing Record 45 of Set 5  | ferkessedougou
# Processing Record 46 of Set 5  | nakonde
# Processing Record 47 of Set 5  | namibe
# Processing Record 48 of Set 5  | novoagansk
# Processing Record 49 of Set 5  | delmas
# Processing Record 50 of Set 5  | varzea da palma
# Processing Record 1 of Set 6  | isangel
# Processing Record 2 of Set 6  | quthing
# Processing Record 3 of Set 6  | adoni
# Processing Record 4 of Set 6  | bilma
# Processing Record 5 of Set 6  | marshalltown
# Processing Record 6 of Set 6  | tabora
# Processing Record 7 of Set 6  | oranjemund
# Processing Record 8 of Set 6  | kerchevskiy
# Processing Record 9 of Set 6  | yunjinghong
# City not found. Skipping...
# Processing Record 10 of Set 6  | saskylakh
# Processing Record 11 of Set 6  | cabo san lucas
# Processing Record 12 of Set 6  | sitka
# Processing Record 13 of Set 6  | hambantota
# Processing Record 14 of Set 6  | cap-chat
# Processing Record 15 of Set 6  | poronaysk
# Processing Record 16 of Set 6  | severo-kurilsk
# Processing Record 17 of Set 6  | semey
# Processing Record 18 of Set 6  | cherskiy
# Processing Record 19 of Set 6  | villa carlos paz
# Processing Record 20 of Set 6  | chuy
# Processing Record 21 of Set 6  | barguzin
# Processing Record 22 of Set 6  | makakilo city
# Processing Record 23 of Set 6  | acari
# Processing Record 24 of Set 6  | port macquarie
# Processing Record 25 of Set 6  | nishihara
# Processing Record 26 of Set 6  | shiyan
# Processing Record 27 of Set 6  | adrar
# Processing Record 28 of Set 6  | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6  | lompoc
# Processing Record 30 of Set 6  | sioux lookout
# Processing Record 31 of Set 6  | shaartuz
# City not found. Skipping...
# Processing Record 32 of Set 6  | tazmalt
# Processing Record 33 of Set 6  | sept-iles
# Processing Record 34 of Set 6  | dingle
# Processing Record 35 of Set 6  | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 6  | vilyuysk
# Processing Record 37 of Set 6  | aberdeen
# Processing Record 38 of Set 6  | airai
# Processing Record 39 of Set 6  | paamiut
# Processing Record 40 of Set 6  | tidore
# City not found. Skipping...
# Processing Record 41 of Set 6  | burica
# City not found. Skipping...
# Processing Record 42 of Set 6  | dogondoutchi
# Processing Record 43 of Set 6  | saint-philippe
# Processing Record 44 of Set 6  | rucheng
# Processing Record 45 of Set 6  | tomatlan
# Processing Record 46 of Set 6  | qaqortoq
# Processing Record 47 of Set 6  | bubaque
# Processing Record 48 of Set 6  | soyo
# Processing Record 49 of Set 6  | makarov
# Processing Record 50 of Set 6  | awjilah
# Processing Record 1 of Set 7  | nuevo progreso
# Processing Record 2 of Set 7  | amahai
# Processing Record 3 of Set 7  | chikoy
# City not found. Skipping...
# Processing Record 4 of Set 7  | coquimbo
# Processing Record 5 of Set 7  | cravo norte
# Processing Record 6 of Set 7  | kathu
# Processing Record 7 of Set 7  | bathsheba
# Processing Record 8 of Set 7  | lai
# Processing Record 9 of Set 7  | shu
# Processing Record 10 of Set 7  | mar del plata
# Processing Record 11 of Set 7  | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 7  | evanton
# Processing Record 13 of Set 7  | chipaque
# Processing Record 14 of Set 7  | verkhoyansk
# Processing Record 15 of Set 7  | soure
# Processing Record 16 of Set 7  | warqla
# City not found. Skipping...
# Processing Record 17 of Set 7  | bom despacho
# Processing Record 18 of Set 7  | batangafo
# Processing Record 19 of Set 7  | humberto de campos
# Processing Record 20 of Set 7  | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 7  | ouallam
# Processing Record 22 of Set 7  | santa rosa
# Processing Record 23 of Set 7  | nivala
# Processing Record 24 of Set 7  | nara
# Processing Record 25 of Set 7  | godo
# Processing Record 26 of Set 7  | olafsvik
# City not found. Skipping...
# Processing Record 27 of Set 7  | asopos
# Processing Record 28 of Set 7  | husavik
# Processing Record 29 of Set 7  | pevek
# Processing Record 30 of Set 7  | kampot
# Processing Record 31 of Set 7  | brejinho
# Processing Record 32 of Set 7  | meulaboh
# Processing Record 33 of Set 7  | kabompo
# Processing Record 34 of Set 7  | bambanglipuro
# Processing Record 35 of Set 7  | itaueira
# Processing Record 36 of Set 7  | bosaso
# Processing Record 37 of Set 7  | anadyr
# Processing Record 38 of Set 7  | tura
# Processing Record 39 of Set 7  | kearney
# Processing Record 40 of Set 7  | mahebourg
# Processing Record 41 of Set 7  | mana
# Processing Record 42 of Set 7  | poso
# Processing Record 43 of Set 7  | tessalit
# Processing Record 44 of Set 7  | poum
# Processing Record 45 of Set 7  | shipitsyno
# Processing Record 46 of Set 7  | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 7  | viedma
# Processing Record 48 of Set 7  | savinka
# Processing Record 49 of Set 7  | boljevac
# Processing Record 50 of Set 7  | pombas
# Processing Record 1 of Set 8  | ikot ekpene
# Processing Record 2 of Set 8  | zyryanka
# Processing Record 3 of Set 8  | kalabagh
# Processing Record 4 of Set 8  | pisco
# Processing Record 5 of Set 8  | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 8  | yingcheng
# Processing Record 7 of Set 8  | show low
# Processing Record 8 of Set 8  | bapatla
# Processing Record 9 of Set 8  | bima
# Processing Record 10 of Set 8  | datong
# Processing Record 11 of Set 8  | midleton
# Processing Record 12 of Set 8  | mouzakion
# City not found. Skipping...
# Processing Record 13 of Set 8  | urucara
# Processing Record 14 of Set 8  | batavia
# Processing Record 15 of Set 8  | praia
# Processing Record 16 of Set 8  | ekhabi
# Processing Record 17 of Set 8  | pakwach
# City not found. Skipping...
# Processing Record 18 of Set 8  | verkhnevilyuysk
# Processing Record 19 of Set 8  | raudeberg
# Processing Record 20 of Set 8  | margate
# Processing Record 21 of Set 8  | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 8  | yanam
# Processing Record 23 of Set 8  | joao pinheiro
# Processing Record 24 of Set 8  | diego de almagro
# Processing Record 25 of Set 8  | goderich
# Processing Record 26 of Set 8  | liaozhong
# Processing Record 27 of Set 8  | luanda
# Processing Record 28 of Set 8  | sigli
# Processing Record 29 of Set 8  | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 8  | aklavik
# Processing Record 31 of Set 8  | maniitsoq
# Processing Record 32 of Set 8  | tarakan
# Processing Record 33 of Set 8  | riyadh
# Processing Record 34 of Set 8  | peace river
# Processing Record 35 of Set 8  | nanortalik
# Processing Record 36 of Set 8  | taburi
# City not found. Skipping...
# Processing Record 37 of Set 8  | falam
# Processing Record 38 of Set 8  | marquette
# Processing Record 39 of Set 8  | loandjili
# Processing Record 40 of Set 8  | arona
# Processing Record 41 of Set 8  | luoyang
# Processing Record 42 of Set 8  | muisne
# Processing Record 43 of Set 8  | inuvik
# Processing Record 44 of Set 8  | la rioja
# Processing Record 45 of Set 8  | okhotsk
# Processing Record 46 of Set 8  | kargil
# Processing Record 47 of Set 8  | college
# Processing Record 48 of Set 8  | codrington
# Processing Record 49 of Set 8  | mayo
# Processing Record 50 of Set 8  | padang
# Processing Record 1 of Set 9  | jabinyanah
# Processing Record 2 of Set 9  | skibbereen
# Processing Record 3 of Set 9  | ucluelet
# Processing Record 4 of Set 9  | pacific grove
# Processing Record 5 of Set 9  | boa vista
# Processing Record 6 of Set 9  | kilindoni
# Processing Record 7 of Set 9  | vershino-shakhtaminskiy
# Processing Record 8 of Set 9  | griffith
# Processing Record 9 of Set 9  | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 9  | barra do garcas
# Processing Record 11 of Set 9  | roberval
# Processing Record 12 of Set 9  | nisia floresta
# Processing Record 13 of Set 9  | ukiah
# Processing Record 14 of Set 9  | kaitangata
# Processing Record 15 of Set 9  | yerbogachen
# Processing Record 16 of Set 9  | shitanjing
# Processing Record 17 of Set 9  | hualmay
# Processing Record 18 of Set 9  | puerto carreno
# Processing Record 19 of Set 9  | gornopravdinsk
# Processing Record 20 of Set 9  | marsh harbour
# Processing Record 21 of Set 9  | bristol
# Processing Record 22 of Set 9  | zaltan
# Processing Record 23 of Set 9  | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 9  | alexandria
# Processing Record 25 of Set 9  | agadez
# Processing Record 26 of Set 9  | ahipara
# Processing Record 27 of Set 9  | kirovskiy
# Processing Record 28 of Set 9  | bialogard
# Processing Record 29 of Set 9  | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 9  | teya
# Processing Record 31 of Set 9  | thessalon
# Processing Record 32 of Set 9  | berdigestyakh
# Processing Record 33 of Set 9  | lagoa
# Processing Record 34 of Set 9  | cockburn town
# Processing Record 35 of Set 9  | amambai
# Processing Record 36 of Set 9  | jiaonan
# Processing Record 37 of Set 9  | narsaq
# Processing Record 38 of Set 9  | krasnoselkup
# City not found. Skipping...
# Processing Record 39 of Set 9  | tiksi
# Processing Record 40 of Set 9  | machinga
# Processing Record 41 of Set 9  | ambon
# Processing Record 42 of Set 9  | sambava
# Processing Record 43 of Set 9  | yarmouth
# Processing Record 44 of Set 9  | san ignacio
# Processing Record 45 of Set 9  | maputo
# Processing Record 46 of Set 9  | kangaatsiaq
# Processing Record 47 of Set 9  | grindavik
# Processing Record 48 of Set 9  | mgandu
# Processing Record 49 of Set 9  | svetlogorsk
# Processing Record 50 of Set 9  | port augusta
# Processing Record 1 of Set 10  | vilhena
# Processing Record 2 of Set 10  | bukama
# Processing Record 3 of Set 10  | jarvenpaa
# Processing Record 4 of Set 10  | grand-santi
# Processing Record 5 of Set 10  | ilmajoki
# Processing Record 6 of Set 10  | ancud
# Processing Record 7 of Set 10  | hobyo
# Processing Record 8 of Set 10  | samarai
# Processing Record 9 of Set 10  | malakal
# City not found. Skipping...
# Processing Record 10 of Set 10  | rosetown
# Processing Record 11 of Set 10  | kargopol
# Processing Record 12 of Set 10  | eslov
# Processing Record 13 of Set 10  | cabedelo
# Processing Record 14 of Set 10  | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 10  | provideniya
# Processing Record 16 of Set 10  | iisalmi
# Processing Record 17 of Set 10  | orgun
# City not found. Skipping...
# Processing Record 18 of Set 10  | okato
# Processing Record 19 of Set 10  | nabire
# Processing Record 20 of Set 10  | rungata
# City not found. Skipping...
# Processing Record 21 of Set 10  | birao
# Processing Record 22 of Set 10  | sao joao da barra
# Processing Record 23 of Set 10  | touros
# Processing Record 24 of Set 10  | yichang
# Processing Record 25 of Set 10  | santa cruz do rio pardo
# Processing Record 26 of Set 10  | lala
# Processing Record 27 of Set 10  | mangrol
# Processing Record 28 of Set 10  | itarema
# Processing Record 29 of Set 10  | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 10  | szigetvar
# Processing Record 31 of Set 10  | baie-comeau
# Processing Record 32 of Set 10  | lalsot
# Processing Record 33 of Set 10  | alakurtti
# Processing Record 34 of Set 10  | labuhan
# Processing Record 35 of Set 10  | constitucion
# Processing Record 36 of Set 10  | felidhoo
# City not found. Skipping...
# Processing Record 37 of Set 10  | kirkwall
# Processing Record 38 of Set 10  | visnes
# Processing Record 39 of Set 10  | quelimane
# Processing Record 40 of Set 10  | raduzhnyy
# Processing Record 41 of Set 10  | liverpool
# Processing Record 42 of Set 10  | cururupu
# Processing Record 43 of Set 10  | halalo
# City not found. Skipping...
# Processing Record 44 of Set 10  | alamosa
# Processing Record 45 of Set 10  | harbin
# Processing Record 46 of Set 10  | plettenberg bay
# Processing Record 47 of Set 10  | mahajanga
# Processing Record 48 of Set 10  | namestovo
# Processing Record 49 of Set 10  | guerande
# Processing Record 50 of Set 10  | solnechnyy
# Processing Record 1 of Set 11  | hastings
# Processing Record 2 of Set 11  | radovitskiy
# Processing Record 3 of Set 11  | cruzeiro do sul
# Processing Record 4 of Set 11  | chingola
# Processing Record 5 of Set 11  | beihai
# Processing Record 6 of Set 11  | uige
# Processing Record 7 of Set 11  | lixourion
# Processing Record 8 of Set 11  | bongandanga
# Processing Record 9 of Set 11  | butembo
# Processing Record 10 of Set 11  | kholodnyy
# Processing Record 11 of Set 11  | dickinson
# Processing Record 12 of Set 11  | santiago
# Processing Record 13 of Set 11  | dongsheng
# Processing Record 14 of Set 11  | henties bay
# Processing Record 15 of Set 11  | beloha
# Processing Record 16 of Set 11  | nizhniy ingash
# Processing Record 17 of Set 11  | baiyin
# Processing Record 18 of Set 11  | aksu
# Processing Record 19 of Set 11  | galgani
# City not found. Skipping...
# Processing Record 20 of Set 11  | lazaro cardenas
# Processing Record 21 of Set 11  | grand haven
# Processing Record 22 of Set 11  | gribanovskiy
# Processing Record 23 of Set 11  | yola
# Processing Record 24 of Set 11  | suruc
# Processing Record 25 of Set 11  | aksarka
# Processing Record 26 of Set 11  | alyangula
# Processing Record 27 of Set 11  | tres arroyos
# Processing Record 28 of Set 11  | hofn
# Processing Record 29 of Set 11  | vila
# Processing Record 30 of Set 11  | vangaindrano
# Processing Record 31 of Set 11  | canas
# Processing Record 32 of Set 11  | ziarat
# Processing Record 33 of Set 11  | russell
# Processing Record 34 of Set 11  | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 11  | akyab
# City not found. Skipping...
# Processing Record 36 of Set 11  | kerteh
# City not found. Skipping...
# Processing Record 37 of Set 11  | madimba
# Processing Record 38 of Set 11  | levelek
# Processing Record 39 of Set 11  | marv dasht
# City not found. Skipping...
# Processing Record 40 of Set 11  | hamilton
# Processing Record 41 of Set 11  | bandarbeyla
# Processing Record 42 of Set 11  | otjimbingwe
# Processing Record 43 of Set 11  | majene
# Processing Record 44 of Set 11  | casa grande
# Processing Record 45 of Set 11  | jurm
# Processing Record 46 of Set 11  | ryotsu
# Processing Record 47 of Set 11  | baturaja
# Processing Record 48 of Set 11  | hargeysa
# Processing Record 49 of Set 11  | dukat
# Processing Record 50 of Set 11  | klaksvik
# Processing Record 1 of Set 12  | provost
# Processing Record 2 of Set 12  | veraval
# Processing Record 3 of Set 12  | benghazi
# Processing Record 4 of Set 12  | janow lubelski
# Processing Record 5 of Set 12  | vestmanna
# Processing Record 6 of Set 12  | udachnyy
# Processing Record 7 of Set 12  | carlagan
# Processing Record 8 of Set 12  | buala
# Processing Record 9 of Set 12  | rostovka
# Processing Record 10 of Set 12  | moyale
# Processing Record 11 of Set 12  | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 12  | maragogi
# Processing Record 13 of Set 12  | enugu
# Processing Record 14 of Set 12  | waddan
# Processing Record 15 of Set 12  | aquin
# Processing Record 16 of Set 12  | fort nelson
# Processing Record 17 of Set 12  | saldanha
# Processing Record 18 of Set 12  | nemuro
# Processing Record 19 of Set 12  | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 12  | chumikan
# Processing Record 21 of Set 12  | erenhot
# Processing Record 22 of Set 12  | pirovskoye
# Processing Record 23 of Set 12  | atar
# Processing Record 24 of Set 12  | chitral
# Processing Record 25 of Set 12  | jampur
# Processing Record 26 of Set 12  | ugad
# Processing Record 27 of Set 12  | tommot
# Processing Record 28 of Set 12  | namatanai
# Processing Record 29 of Set 12  | maxixe
# Processing Record 30 of Set 12  | synya
# Processing Record 31 of Set 12  | nizhneudinsk
# Processing Record 32 of Set 12  | yaan
# Processing Record 33 of Set 12  | jalu
# Processing Record 34 of Set 12  | marrakesh
# Processing Record 35 of Set 12  | todos santos
# Processing Record 36 of Set 12  | gizo
# Processing Record 37 of Set 12  | usolye
# Processing Record 38 of Set 12  | inirida
# Processing Record 39 of Set 12  | flin flon
# Processing Record 40 of Set 12  | alenquer
# Processing Record 41 of Set 12  | forset
# City not found. Skipping...
# Processing Record 42 of Set 12  | jiuquan
# Processing Record 43 of Set 12  | shaowu
# Processing Record 44 of Set 12  | ballina
# Processing Record 45 of Set 12  | esna
# Processing Record 46 of Set 12  | lisala
# Processing Record 47 of Set 12  | tres lagoas
# City not found. Skipping...
# Processing Record 48 of Set 12  | belaya gora
# Processing Record 49 of Set 12  | bikaner
# Processing Record 50 of Set 12  | evenskjaer
# City not found. Skipping...
# Processing Record 1 of Set 13  | manggar
# Processing Record 2 of Set 13  | fortuna
# Processing Record 3 of Set 13  | san felipe
# Processing Record 4 of Set 13  | zhigansk
# Processing Record 5 of Set 13  | chadan
# Processing Record 6 of Set 13  | nome
# Processing Record 7 of Set 13  | darab
# Processing Record 8 of Set 13  | jilib
# Processing Record 9 of Set 13  | grand gaube
# Processing Record 10 of Set 13  | tazovskiy
# Processing Record 11 of Set 13  | lockhart
# Processing Record 12 of Set 13  | marawi
# Processing Record 13 of Set 13  | dandeli
# Processing Record 14 of Set 13  | southampton
# Processing Record 15 of Set 13  | kedrovyy
# Processing Record 16 of Set 13  | gannan
# Processing Record 17 of Set 13  | jinchang
# Processing Record 18 of Set 13  | saint anthony
# Processing Record 19 of Set 13  | calatayud
# Processing Record 20 of Set 13  | kapoeta
# City not found. Skipping...
# Processing Record 21 of Set 13  | dudinka
# Processing Record 22 of Set 13  | penalva
# Processing Record 23 of Set 13  | lasa
# Processing Record 24 of Set 13  | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 13  | bhainsdehi
# Processing Record 26 of Set 13  | acajutla
# Processing Record 27 of Set 13  | asfi
# City not found. Skipping...
# Processing Record 28 of Set 13  | marjamaa
# Processing Record 29 of Set 13  | kalat
# Processing Record 30 of Set 13  | prince rupert
# Processing Record 31 of Set 13  | banjarmasin
# Processing Record 32 of Set 13  | orje
# Processing Record 33 of Set 13  | muroto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dataframe from data retrieved
city_dic={
    "City":city2,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max_Temp":max_temp,
    "Wind_Speed":wind_speed
}
city_data=pd.DataFrame(city_dic)
city_data.to_csv('city_data.csv')
city_data.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  busselton          26      AU  2020-01-07        55 -33.64  115.35
# 1    kahului          40      US  2020-01-07        61  20.89 -156.47
# 2     matara         100      BI  2020-01-07        88  -3.48   29.48
# 3   tasiilaq         100      GL  2020-01-07        75  65.61  -37.64
# 4       lata         100      IN  2020-01-07        97  30.78   78.62
#
#    Max_Temp  Wind_Speed
# 0     64.00        4.45
# 1     78.80       14.99
# 2     58.01        3.62
# 3      8.82       28.14
# 4     14.27        4.14

# %%
#date of data retrivial
for city in city_data['Date']:
    date=datetime.datetime.fromtimestamp(int(city)).strftime('%Y-%m-%d')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plot=city_data.plot(kind='scatter',x='Lat',y='Max_Temp',grid=True, title=f"City Latitude vs. Temperature (F) on {date}")
fig=plot.get_figure()
plt.show()
fig.savefig(f'../Images/lat_temp_scatter.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plot=city_data.plot(kind='scatter',x='Lat',y='Humidity',grid=True, title=f"City Latitude vs. Humidity on {date}")
fig=plot.get_figure()
plt.show()
fig.savefig(f'../Images/lat_humidity_scatter.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plot=city_data.plot(kind='scatter',x='Lat',y='Cloudiness',grid=True, title=f"City Latitude vs. Cloudiness on {date}")
fig=plot.get_figure()
plt.show()
fig.savefig(f'../Images/lat_cloudiness_scatter.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plot=city_data.plot(kind='scatter',x='Lat',y='Wind_Speed',grid=True, title=f"City Latitude vs. Wind Speed on {date}")
fig=plot.get_figure()
plt.show()
fig.savefig(f'../Images/lat_wind_scatter.png')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linerplot(x,y):
    (slope,intercept,rvalue,_,_)=linregress(x,y)
    fit=(slope*x)+intercept
    fig, ax=plt.subplots()
    ax.scatter(x, y)
    ax.plot(x,fit,c='r')
    ax.set_xlabel(x.name)
    ax.set_ylabel(y.name)
    ax.text(min(x),min(y),f"y={round(slope,2)}x + {round(intercept,2)}",c='r')
    if min(x)>=0:
        plt.savefig(f'../Images/north_{x.name}_{y.name}_linear_regression.png')
    else:
        plt.savefig(f'../Images/south_{x.name}_{y.name}_linear_regression.png')
    plt.show()
    print(f"The r-squared is : {rvalue}")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_cities=city_data.loc[city_data['Lat']>=0]
south_cities=city_data.loc[city_data['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linerplot(north_cities['Lat'],north_cities['Max_Temp'])
# Out:
# The r-squared is : -0.8259523037058778

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linerplot(south_cities['Lat'],south_cities['Max_Temp'])
# Out:
# The r-squared is : 0.4969203716864849

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linerplot(north_cities['Lat'],north_cities['Humidity'])
# Out:
# The r-squared is : 0.3785181645563671

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linerplot(south_cities['Lat'],south_cities['Humidity'])
# Out:
# The r-squared is : 0.33305010598732443

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linerplot(north_cities['Lat'],north_cities['Cloudiness'])
# Out:
# The r-squared is : 0.2804742397978768

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linerplot(south_cities['Lat'],south_cities['Cloudiness'])
# Out:
# The r-squared is : 0.2770757894726635

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linerplot(north_cities['Lat'],north_cities['Wind_Speed'])
# Out:
# The r-squared is : 0.16329392557125497

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linerplot(south_cities['Lat'],south_cities['Wind_Speed'])
# Out:
# The r-squared is : -0.20952700673255956
